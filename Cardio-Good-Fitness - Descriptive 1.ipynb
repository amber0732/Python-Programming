# %% [markdown]
# # Lets Explore the Cardio Fitness Dataset by using Data Visualization Library of Python :-

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("CardioGoodFitness-1.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ## First 4 observations :-

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# ## Last 4 observation :-

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()    # Random Observation
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 153   TM798   25   Male         18     Partnered      4        3   64741
#
#      Miles
# 153    100

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 118   TM498   32    Male         16        Single      4        3   60261
# 155   TM798   25    Male         18     Partnered      6        5   75946
# 158   TM798   26    Male         16     Partnered      5        4   64741
# 160   TM798   27    Male         18        Single      4        3   88396
# 24    TM195   24    Male         14        Single      2        3   45480
# 125   TM498   34  Female         16     Partnered      4        3   64809
# 1     TM195   19    Male         15        Single      2        3   31836
# 169   TM798   30    Male         18     Partnered      5        5   99601
# 16    TM195   23  Female         14        Single      2        3   34110
# 81    TM498   20    Male         14        Single      2        3   32973
#
#      Miles
# 118    127
# 155    240
# 158    180
# 160    100
# 24     113
# 125     95
# 1       75
# 169    150
# 16     103
# 81      53

# %%
df.shape           ##Total no. of Rows and Columns
# Out:
# (180, 9)

# %%
df.index          ##Total no. of Index
# Out:
# RangeIndex(start=0, stop=180, step=1)

# %%
df.columns       ##Total no. of Columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df.dtypes        ## Datatypes of data present in Columns
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()       ## Detailed Information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull()
# Out:
#      Product    Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0      False  False   False      False          False  False    False   False
# 1      False  False   False      False          False  False    False   False
# 2      False  False   False      False          False  False    False   False
# 3      False  False   False      False          False  False    False   False
# 4      False  False   False      False          False  False    False   False
# ..       ...    ...     ...        ...            ...    ...      ...     ...
# 175    False  False   False      False          False  False    False   False
# 176    False  False   False      False          False  False    False   False
# 177    False  False   False      False          False  False    False   False
# 178    False  False   False      False          False  False    False   False
# 179    False  False   False      False          False  False    False   False
#
#      Miles
# 0    False
# ...

# %%
df.isnull().sum()       ## Detailed Information of Missing/Null Values.
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe()           ## Statistical Data of the dataset.
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include = "all")         ## Entier Detailed Statistical Data of the dataset.
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# ## Now Let's Create some interting Graphs for the dataset :-

# %% [markdown]
# ## 1. Histogram :-

# %%
plt.hist(df["Product"])
plt.title("Produt Distribution", fontsize = 20)
plt.xlabel("Products", fontsize = 15)
plt.ylabel("Counts", fontsize = 15)
plt.show()

# %%
sns.hist("Age")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.hist("Age")
#
# AttributeError: module 'seaborn' has no attribute 'hist'

# %%
plt.hist(df["MaritalStatus"], color = "Red")
plt.title("Marital Status Distribution", fontsize = 20, color = "Teal")
plt.xlabel("Marital Status", fontsize = 15, color = "Teal")
plt.ylabel("Counts", fontsize = 15, color = "Teal")
plt.show()

# %%
## Histogram formation from the method of Bar Graph :-

df["Age"].value_counts().plot(kind = "hist", color = "Orange")
plt.title("Age Distribution", fontsize = 20, color = "Green")
plt.xlabel("Age", fontsize = 15, color = "Green")
plt.ylabel("Frequency", fontsize = 15, color = "Green")
plt.show()

# %% [markdown]
# ## 2. Boxplot :-

# %%
sns.boxplot(df["Education"], color = "Purple")
plt.title("Education Distribution", fontsize = 20, color = "Green")
plt.xlabel("Level", fontsize = 15, color = "Green")
plt.ylabel("Education", fontsize = 15, color = "Green")
plt.show()

# %%
## We cannot make Boxplot from bar graph method.

df["Age"].value_counts().plot(kind = "boxplot", color = "Orange")
plt.title("Age Distribution", fontsize = 20, color = "Green")
plt.xlabel("Age", fontsize = 15, color = "Green")
plt.ylabel("Frequency", fontsize = 15, color = "Green")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 ## We cannot make Boxplot from bar graph method.
# ----> 3 df["Age"].value_counts().plot(kind = "boxplot", color = "Orange")
#       4 plt.title("Age Distribution", fontsize = 20, color = "Green")
#       5 plt.xlabel("Age", fontsize = 15, color = "Green")
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:933, in PlotAccessor.__call__(self, *args, **kwargs)
#     930     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     932 if kind not in self._all_kinds:
# --> 933     raise ValueError(f"{kind} is not a valid plot kind")
#     935 # The original data structured can be transformed before passed to the
#     936 # backend. For example, for DataFrame is common to set the index as the
#     937 # `x` parameter, and return a Series with the parameter `y` as values.
# ...

# %% [markdown]
# ## 3. Bar Graph :-

# %%
df["MaritalStatus"].value_counts().plot(kind = "bar", color = "Green")
plt.title("MaritalStatus Distribution", fontsize = 20, color = "Red")
plt.xlabel("MaritalStatus", fontsize = 15, color = "Red")
plt.ylabel("Frequency", fontsize = 15, color = "Red")
plt.show()

# %%
df["Fitness"].value_counts().plot(kind = "barh", color = "Black")
plt.title("Fitness Distribution", fontsize = 20, color = "Orange")
plt.xlabel("Frequency", fontsize = 15, color = "Orange")
plt.ylabel("Fitness", fontsize = 15, color = "Orange")
plt.show()

# %% [markdown]
# ## 4. Pie Chart :-

# %%
gen = df["Gender"].value_counts()
keys = gen.keys().to_list()
counts = gen.to_list()
plt.pie(x = counts, labels = keys, autopct = "%1.1f%%")
plt.title("Gender Distribution", fontsize = 20, color = "Brown")
plt.show()

# %%
from matplotlib import cm
pro = df["Product"].value_counts()
keys = pro.keys().to_list()
counts = pro.to_list()
cs = cm.Set1([2, 4, 6, 8])
plt.pie(x = counts, labels = keys, autopct = "%1.1f%%", colors = cs)
plt.title("Product Distribution", fontsize = 20, color = "Brown")
plt.show()

# %%
inc = df["Income"].value_counts()
keys = inc.keys().to_list()
counts = inc.to_list()
cs = cm.Set2([1, 1, 1, 1])
plt.pie(x = counts, labels = keys, autopct = "%1.1f%%")
plt.title("Bar Graph for Icopme Distribution", color = "Red", fontsize = 20)
plt.show()

# %% [markdown]
# ## 5. Scatter-Dot Graph :-

# %%
plt.scatter(x = "Age", y = "Gender", data = df, color = "teal")
plt.title("Age and Gender Distribution", fontsize = 20, color = "Purple")
plt.xlabel("Age", fontsize = 15, color = "Purple")
plt.ylabel("Gender", fontsize = 15, color = "Purple")
plt.show()

# %%
plt.scatter(x = "MaritalStatus", y = "Education", data = df, color = "Gray")
plt.title("Education and Marital Status Distribution", fontsize = 20, color = "Purple")
plt.xlabel("MaritalStatus", fontsize = 15, color = "Purple")
plt.ylabel("Education", fontsize = 15, color = "Purple")
plt.show()

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# # 6. Countplot :-
# ## Countplot is used for only Catagorical Attributes.
# ## Countplot can be used for either One Catagorical Attributes or two Catagorical Attributes.

# %%
sns.countplot(df["Education"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x="Product", data = df)
plt.title("Product Distribution")
plt.show()

# %%
sns.countplot(x="Product", hue = "Gender", data = df)
plt.title("Product & Gender Distribution")
plt.show()

# %%
sns.countplot(x="Product", hue = "MaritalStatus", data = df)
plt.title("Product & MaritalStatus Distribution")
plt.show()

# %% [markdown]
# ## 7. All Histograms with figured Size :-

# %%
df.hist(figsize = (10, 20))
plt.show()

# %% [markdown]
# # When to use Boxplot :-
# ## 1. For One Numerical Attribute :-

# %%
sns.boxplot(x = "Age", data = df)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## 2. For One Catagorical Attribute & One Numerical Attribute :-

# %%
sns.boxplot(x = "Product", y = "Age", data = df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %% [markdown]
# # Crosslab :-
# ## It is used for two Catagorical Attribute's table format.

# %%
pd.crosstab(df["Product"], df["Gender"])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %% [markdown]
# # 8. Pairplot :-
# ## Showing the Covarience and Correlation on the basis of Statistical Data :-

# %%
sns.pairplot(df, diag_kind = "kde")
plt.show()

# %% [markdown]
# ## Correlation :-

# %%
corr = df.corr()
corr
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8576\2438084875.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# # Heatmap visualization :-

# %%
sns.heatmap(corr, annot = True, cmap = "YlGnBu")
plt.show()

# %%
sns.heatmap(corr, cmap = "YlGnBu")
plt.show()

# %%
import seaborn as sns

# %%
sns.heatmap(corr, annot = True)   ## Without Color code:-
plt.show()

# %%
sns.heatmap(corr, annot = False)   ## Without Color code:-
plt.show()

# %%
df.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ## Note :- Best case to remove outliers is median in numerical data also with mean for moderate case. And for Catagorical data use mode to replace outliers.

# %% [markdown]
# ## Let's Remove the Outiers :-

# %%
df.boxplot("Age")
# Out:
# <Axes: >

# %% [markdown]
# ## Steps for Removing the Outliers :-

# %%
def remove_outlier(col):
    sorted(col)
    q1,q3 = col.quantile([0.25, 0.75])
    iqr = q3 - q1
    lower_range = q1 - (1.5*iqr)
    upper_range = q3 + (1.5*iqr)
    return lower_range, upper_range

# %%
lowage, uppage = remove_outlier(df["Age"])
df["Age"] = np.where(df["Age"]>uppage, uppage, df["Age"])
df["Age"] = np.where(df["Age"]<lowage, lowage, df["Age"])

# %% [markdown]
# ## Outliers are Removed :-

# %%
df.boxplot("Age")
# Out:
# <Axes: >

# %%
print("END")
# Out:
# END
